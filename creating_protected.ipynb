# %%
import pandas as pd

# %%
df = pd.read_csv('./data/preprocessed.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                             umich_user_id  answer_count  \
# 0           0  d8494a39cae7ac5417d491df43f8296a285b3cd6           0.0
# 1           1  9c3e969ace3d1278a5e3ad42fa80dfc20379aaf5           0.0
# 2           2  c91dab5c98bead9e683d15e9e2cc2c4584a8e626          10.0
# 3           3  2246b3c08e2f3ee5d17f125ccc70baf3691667f9           5.0
# 4           4  1f8331ad9f0125b0fc85a1c4ff28f9c198b6fca2          11.0
#
#    average_answer_length  total_votes_given_answers  \
# 0               0.000000                        0.0
# 1               0.000000                        0.0
# 2             797.200000                        0.0
# 3             589.000000                        1.0
# 4             300.818182                        3.0
#
#    total_votes_received_answers  question_count  average_question_length  \
# 0                           0.0             0.0                 0.000000
# 1                           0.0             0.0                 0.000000
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['umich_user_id', 'answer_count', 'average_answer_length',
#        'total_votes_given_answers', 'total_votes_received_answers',
#        'question_count', 'average_question_length',
#        'total_votes_given_questions', 'total_votes_received_questions',
#        'total_questions_following', 'country_cd_US', 'is_female',
#        'bachelor_obtained', 'white', 'completed'],
#       dtype='object')

# %%
protected = ['country_cd_US', 'is_female',
       'bachelor_obtained', 'white']

# %%
all = df.columns

# %%
new_df = pd.DataFrame(0, columns=all, index=df.index)

# %%
new_df[protected] = 1

# %%
new_df.head()
# Out:
#    umich_user_id  answer_count  average_answer_length  \
# 0              0             0                      0
# 1              0             0                      0
# 2              0             0                      0
# 3              0             0                      0
# 4              0             0                      0
#
#    total_votes_given_answers  total_votes_received_answers  question_count  \
# 0                          0                             0               0
# 1                          0                             0               0
# 2                          0                             0               0
# 3                          0                             0               0
# 4                          0                             0               0
#
#    average_question_length  total_votes_given_questions  \
# 0                        0                            0
# 1                        0                            0
# ...

# %%
new_df['completed'] = 2

# %%
new_df = new_df.drop(['umich_user_id'], axis=1)

# %%
new_df.to_csv('protected.csv', index=False)

# %%
new_df = new_df.iloc[:1]
new_df.to_csv('protected.csv', index=False)

# %%
df = pd.read_csv('./preprocessed.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df = df.drop(['umich_user_id'], axis=1)

# %%
df.to_csv('preprocessed.csv', index=False)

# %%
df.head()
# Out:
#    answer_count  average_answer_length  total_votes_given_answers  \
# 0           0.0               0.000000                        0.0
# 1           0.0               0.000000                        0.0
# 2          10.0             797.200000                        0.0
# 3           5.0             589.000000                        1.0
# 4          11.0             300.818182                        3.0
#
#    total_votes_received_answers  question_count  average_question_length  \
# 0                           0.0             0.0                 0.000000
# 1                           0.0             0.0                 0.000000
# 2                           0.0             0.0               797.200000
# 3                           1.0             1.0               589.000000
# 4                           3.0             0.0               300.818182
#
#    total_votes_given_questions  total_votes_received_questions  \
# ...
